# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.metrics import r2_score

# %%
data =pd.read_csv('student_performance_dataset.csv')
data.head
# Out:
# <bound method NDFrame.head of       student_id   first_name  last_name                                email  \
# 0              1       Justin       Hall               justin.hall1@email.com
# 1              2        Derek      Brown               derek.brown2@email.com
# 2              3       Shelly     Wright             shelly.wright3@email.com
# 3              4      Raymond    Hawkins           raymond.hawkins4@email.com
# 4              5        Lucas     Jensen              lucas.jensen5@email.com
# ...          ...          ...        ...                                  ...
# 4995        4996        Brian    Stevens          brian.stevens4996@email.com
# 4996        4997  Christopher  Patterson  christopher.patterson4997@email.com
# 4997        4998       Nathan     Norton          nathan.norton4998@email.com
# 4998        4999         Ryan    Collins           ryan.collins4999@email.com
# 4999        5000      Clinton     Newman         clinton.newman5000@email.com
#
#       gender  age         department  attendance(%)  midterm_score  \
# 0       Male   24   Computer Science           90.2             89
# 1       Male   21  Political Science           80.7             58
# 2       Male   18            History           82.1             74
# 3       Male   23            Physics           74.6             66
# 4       Male   19  Political Science           89.2             43
# ...      ...  ...                ...            ...            ...
# 4995  Female   18            History           93.3             40
# 4996    Male   24          Economics           78.8             75
# 4997    Male   23   Computer Science           88.2             58
# 4998  Female   23   Computer Science           73.0             75
# 4999    Male   18   Computer Science          100.0             77
#
#       final_score  ...  quizzes_avg  participation_score  projects_score  \
# 0              68  ...         59.8                   66              79
# 1              61  ...         60.7                   60              69
# 2              55  ...         62.6                   60              57
# 3              69  ...         67.7                   60              67
# 4              40  ...         59.2                   60              58
# ...           ...  ...          ...                  ...             ...
# 4995           63  ...         63.6                   62              57
# 4996           88  ...         84.3                   62              75
# 4997           60  ...         50.0                   60              51
# 4998           63  ...         65.6                   79              73
# 4999           59  ...         58.2                   73              64
#
#       total_score  grade study_hours_per_week  internet_access  \
# 0            76.1      C                    9               no
# 1            60.6      D                   12              yes
# 2            61.3      D                    9              yes
# 3            65.9      D                    5              yes
# 4            45.7      F                   12              yes
# ...           ...    ...                  ...              ...
# 4995         55.9      F                   12              yes
# 4996         80.8     B-                   10              yes
# 4997         57.0      F                    6              yes
# 4998         67.9      D                    5              yes
# 4999         67.2      D                   11              yes
#
#      parent_education family_income stress_level
# 0           Associate        medium            3
# 1          Bachelor's           low            6
# 2         High School        medium            4
# 3         High School        medium            7
# 4          Bachelor's        medium            8
# ...               ...           ...          ...
# 4995      High School        medium            7
# 4996      High School        medium            5
# 4997        Associate           low            6
# 4998       Bachelor's        medium            6
# 4999         Master's           low            9
#
# [5000 rows x 21 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   first_name            5000 non-null   object
#  2   last_name             5000 non-null   object
#  3   email                 5000 non-null   object
#  4   gender                5000 non-null   object
#  5   age                   5000 non-null   int64
#  6   department            5000 non-null   object
#  7   attendance(%)         5000 non-null   float64
#  8   midterm_score         5000 non-null   int64
#  9   final_score           5000 non-null   int64
#  10  assignment_avg        5000 non-null   float64
#  11  quizzes_avg           5000 non-null   float64
#  12  participation_score   5000 non-null   int64
#  13  projects_score        5000 non-null   int64
#  14  total_score           5000 non-null   float64
#  15  grade                 5000 non-null   object
#  16  study_hours_per_week  5000 non-null   int64
#  17  internet_access       5000 non-null   object
#  18  parent_education      5000 non-null   object
#  19  family_income         5000 non-null   object
#  20  stress_level          5000 non-null   int64
# dtypes: float64(4), int64(8), object(9)
# memory usage: 820.4+ KB

# %%
#Input and OutPut 
x =data[['study_hours_per_week']]
y =data[['final_score']]


# train model
model =LinearRegression()
model.fit(x,y)
predicted_scores =model.predict(X)

## valid regression metrix
mae = mean_absolute_error(y,predicted_scores)
mse = mean_squared_error(y,predicted_scores)
rmse = np.sqrt(mse)
r2 = r2_score(y,predicted_scores)
print("Means Absolute Error (MAE):",round(mae,2))
print("Means Squared Error (MSE):",round(mse,2))
print("Root Means Absolute Error (RMSE):",round(rmse,2))
print("R2 Score:",round(r2,2))
# Out:
# Means Absolute Error (MAE): 12.09
# Means Squared Error (MSE): 209.61
# Root Means Absolute Error (RMSE): 14.48
# R2 Score: 0.03

# %%
plt.figure(figsize=(10,6))

plt.hist(data['final_score'],bins=30,color='skyblue',edgecolor='black')
plt.title('Distribution of FINAL EXAM SCORES')
plt.xlabel("Final Exam's Score")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()
plt.tight_layout()

# %%
# Scatter +Regression line

plt.scatter(x,y,color='blue',label='Actual Scores')
plt.plot(x,predicted_scores,color="red",label="Predicted Score (Regression line)")
plt.title('Model prediction vs Actual Score')
plt.xlabel("Study Hours per week ")
plt.ylabel("Final Output ")
plt.grid(True)
plt.show()

# %%
new_hours = 9
predicted_new_Score =model.predict([[new_hours]])
print(f"Predicted final Score for  {new_hours}  hours is {predicted_new_Score} Score ")
# Out:
# Predicted final Score for  9  hours is [[64.6605883]] Score
# /home/miskatul-masabi/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
