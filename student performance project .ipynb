# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

# %%
data =pd.read_csv('synthetic_student_performance.csv')
data.head(5)
# Out:
# Generating 5000 student records...
# Dataset generated successfully!
# Dataset shape: (5000, 21)
#
# First few rows:
#    student_id  first_name  last_name                            email  gender  \
# 0           1      Justin       Hall           justin.hall1@email.com    Male
# 1           2       Derek      Brown           derek.brown2@email.com    Male
# 2           3      Shelly     Wright         shelly.wright3@email.com    Male
# 3           4     Raymond    Hawkins       raymond.hawkins4@email.com    Male
# 4           5       Lucas     Jensen          lucas.jensen5@email.com    Male
# 5           6     William    Andrade       william.andrade6@email.com    Male
# 6           7       Angel  Mcfarland       angel.mcfarland7@email.com    Male
# 7           8       Allen       Carr            allen.carr8@email.com    Male
# 8           9  Jacqueline  Carpenter  jacqueline.carpenter9@email.com    Male
# 9          10        Dawn      Smith           dawn.smith10@email.com  Female
#
#    age         department  attendance(%)  midterm_score  final_score  ...  \
# 0   24   Computer Science           90.2             89           68  ...
# 1   21  Political Science           80.7             58           61  ...
# 2   18            History           82.1             74           55  ...
# 3   23            Physics           74.6             66           69  ...
# 4   19  Political Science           89.2             43           40  ...
# 5   19         Psychology           96.0             57           71  ...
# 6   18        Mathematics           92.8             59           45  ...
# 7   24            Physics           79.8             55           67  ...
# 8   21           Business           82.4             67           73  ...
# 9   20   Computer Science           64.8             64           50  ...
#
#    quizzes_avg  participation_score  projects_score  total_score  grade  \
# 0         59.8                   66              79         76.1      C
# 1         60.7                   60              69         60.6      D
# 2         62.6                   60              57         61.3      D
# 3         67.7                   60              67         65.9      D
# 4         59.2                   60              58         45.7      F
# 5         68.6                   61              52         63.2      D
# 6         55.8                   62              72         54.6      F
# 7         56.4                   62              61         62.0      D
# 8         70.3                  100              70         73.1      C
# 9         50.0                   60              51         54.9      F
#
#   study_hours_per_week  internet_access parent_education family_income  \
# 0                    9               no        Associate        medium
# 1                   12              yes       Bachelor's           low
# 2                    9              yes      High School        medium
# 3                    5              yes      High School        medium
# 4                   12              yes       Bachelor's        medium
# 5                    5              yes         Master's        medium
# 6                    8               no        Associate        medium
# 7                   17              yes       Bachelor's          high
# 8                   14              yes       Bachelor's           low
# 9                   12              yes       Bachelor's        medium
#
#   stress_level
# 0            3
# 1            6
# 2            4
# 3            7
# 4            8
# 5            6
# 6            7
# 7            8
# 8            6
# 9            6
#
# [10 rows x 21 columns]
#
# Grade distribution:
# grade
# A       17
# B      361
# B+      89
# B-     437
# C      581
# C+     477
# C-     378
# D     1099
# F     1561
# Name: count, dtype: int64
#
# Department distribution:
# department
# Psychology            440
# Business              434
# Mathematics           429
# Engineering           425
# History               424
# Political Science     421
# Chemistry             418
# Physics               416
# Computer Science      404
# English Literature    403
# Biology               398
# Economics             388
# Name: count, dtype: int64

# %%
X = data[['Hours']]
